# %% [markdown]
# <a href="https://colab.research.google.com/github/khajum/python/blob/main/python/execrise-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
seconds_in_a_day=23 * 60*60
seconds_in_a_day
# Out:
# 82800

# %%
seconds_in_a_week=7*seconds_in_a_day
seconds_in_a_week
# Out:
# 579600
